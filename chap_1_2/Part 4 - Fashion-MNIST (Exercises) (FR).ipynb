# %% [markdown]
# # Classification de Fashion-MNIST
#
# À votre tour de construire et d’entraîner un réseau de neurones. Vous utiliserez le [jeu de données Fashion-MNIST](https://github.com/zalandoresearch/fashion-mnist), un remplacement direct de MNIST. MNIST est assez simple pour les réseaux de neurones, qui peuvent facilement dépasser 97 % de précision. Fashion-MNIST est un ensemble d’images en niveaux de gris de vêtements, de taille 28x28. Plus complexe que MNIST, il représente mieux les performances réelles d’un réseau et les jeux de données rencontrés dans la pratique.
#
# <img src='assets/fashion-mnist-sprite.png' width=500px>
#
# Dans ce notebook, vous construirez votre propre réseau de neurones. Vous pourriez en grande partie copier le code de la partie 3, mais vous n’apprendriez pas autant. Il est important d’écrire vous-même le code et de le faire fonctionner. N’hésitez pas à consulter les notebooks précédents pendant votre travail.
#
# Commençons par charger le jeu de données avec torchvision.

# %%
import torch
from torchvision import datasets, transforms
import helper

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])
# Download and load the training data
trainset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %% [markdown]
# Voici l’une des images.

# %%
image, label = next(iter(trainloader))
helper.imshow(image[0,:]);

# %% [markdown]
# ## Construire le réseau
#
# Définissez ici votre réseau. Comme pour MNIST, chaque image de 28x28 contient 784 pixels et il y a 10 classes. Ajoutez au moins une couche cachée. Nous vous conseillons d’utiliser des activations ReLU et de renvoyer les logits ou le log-softmax depuis la passe avant. Vous choisissez le nombre et la taille des couches.

# %%
# TODO: Define your network architecture here

# %% [markdown]
# # Entraîner le réseau
#
# Créez maintenant votre réseau et entraînez-le. Définissez d’abord [le critère](http://pytorch.org/docs/master/nn.html#loss-functions) (par exemple `nn.CrossEntropyLoss`) et [l’optimiseur](http://pytorch.org/docs/master/optim.html) (généralement `optim.SGD` ou `optim.Adam`).
#
# Écrivez ensuite le code d’entraînement. Rappelez-vous que la passe d’entraînement suit un processus simple :
#
# * Effectuer une passe avant dans le réseau to get the logits
# * Use the logits to calculate the loss
# * Effectuer une passe arrière avec `loss.backward()` pour calculer les gradients
# * Faire une étape avec l’optimiseur pour mettre à jour les poids
#
# En ajustant les hyperparamètres (unités cachées, taux d’apprentissage, etc.), vous devriez obtenir une perte d’entraînement inférieure à 0,4.

# %%
# TODO: Create the network, define the criterion and optimizer

# %%
# TODO: Train the network here

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper

# Test out your network!

dataiter = iter(testloader)
images, labels = dataiter.next()
img = images[0]
# Convert 2D image to 1D vector
img = img.resize_(1, 784)

# TODO: Calculate the class probabilities (softmax) for img
ps = 

# Plot the image and probabilities
helper.view_classify(img.resize_(1, 28, 28), ps, version='Fashion')
