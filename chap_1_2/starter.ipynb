# %%
import torch.nn as nn # import neural network module from pytorch
import torch

# %%
# créons un tensor composé de 3 éléments 

input_tensor = torch.tensor([0.34, 0.302, -1.404], dtype=torch.float32)

# %%
# taille
28*28 = 
224*224 =

# %%
# definir le layer

layer = nn.Linear(
    in_features=3,  # nombre d'éléments dans le tensor d'entrée
    out_features=2,  # nombre d'éléments dans le tensor de sortie
)

# %%
output_tensor = layer(input_tensor)
output_tensor
# Out:
# tensor([-0.0967, -0.0003], grad_fn=<ViewBackward0>)

# %%
print("weight", layer.weight)
# Out:
# weight Parameter containing:
# tensor([[-0.5766, -0.1912, -0.4012],
#         [-0.0523, -0.4127,  0.3784]], requires_grad=True)

# %%
print("biais" ,layer.bias)
# Out:
# biais Parameter containing:
# tensor([ 0.2363, -0.5517], requires_grad=True)

# %%
n_classes = 2
n_features = 3

# %%
# MLP
model = nn.Sequential(
    nn.Linear(n_features, 8),
    nn.Linear(8, 4),
    nn.Linear(4, n_classes)
)

# %%
model = nn.Sequential(
    nn.Linear(8,4),
    nn.Linear(4,2))

# %%
#calculons le nombre de paramètres du modèle
total = 0

for params in model.parameters():
    total += params.numel()
    #print(params.numel())

total
# Out:
# 46
